# %%
'''[Q1-answer:-]'''

# who develope python  programming language?
''' Python was developed by Guido Van Rossam in 1989 while working at National Research Institute of Netherlands.
    But official python was made available to public in 1991.'''

# %%
'''[Q2-answer:-]'''

#which type of programming does python support?
''' python is an interpreted, interactive, object-oriented programming language.'''

# %%
'''[Q3-answer:-]'''

# Is python case sensitive when dealing with identifiers?
''' Yes, python is case sensitive language for example 
    name = "Rahul"
    NAME = "shyam"
note:- name and NAME both are different in python programming language'''

# %%
'''[Q4-answer:-]'''

# what is the correct extension of python files?
''' The correct extension of python files is .py

# %%
'''[Q5-answer:-]'''

# Is python code compiled or interpreted?
''' python code is interpreted, not compiled'''

# %%
'''[Q6-answer:-]'''

#Name a few blocks of code used to define in python language?
'''In Python, code is organized into blocks using indentation. Indentation is a fundamental aspect of
Python's syntax, and it is used to define blocks of code. Here are a few common types of code blocks in Python:

(1) Fuction Definition:-
'''
def my_function():
    # Code inside the function
    
'''
(2) Conditional Statement (if,elif,else)
'''
if condition:
    # Code to execute if the condition is True
elif another_condition:
    # Code to execute if another_condition is True
else:
    # Code to execute if none of the conditions are True
    
'''
(3) Loops (for and while)
'''
for item in iterable:
    # Code to repeat for each item in the iterable

while condition:
    # Code to execute while the condition is True
'''
(4) Classes and Methods
'''
class MyClass:
    def __init__(self):
        # Constructor method

    def my_method(self):
        # Method definition
'''
(5) Exceptional Handling(try,except,finally)
'''
try:
    # Code that may raise an exception
except ExceptionType as e:
    # Code to handle the exception
finally:
    # Code that always runs, whether there was an exception or not
'''
(6) Context Managers(with statement)
'''
with open("file.txt", "r") as file:
    # Code to work with the file inside the context manager

# %%
'''[Q7-answer:-]'''

#state a character used to give single line comments in python?
'''
In Python, you can use the hash symbol (#) to write single-line comments. Any text following a # on the
same line is treated as a comment and is ignored by the Python interpreter. Here's an example:
'''
# This is a single-line comment
print("Hello, World!")  # This is another comment after code

# %%
'''[Q8-answer:-]'''

#You can use the following functions and methods to find the version of Python that you are currently working with?
'''
You can use the following functions and methods to find the version of Python
that you are currently working with:

(1) sys Module:-
You can use the sys module to access Python's version information.
'''
import sys
print(sys.version)  # Prints the Python version

'''
(2) platform Module:-
The platform module provides various functions to access system-related
information, including Python version.
'''
import platform
print(platform.python_version())  # Prints the Python version as a string

'''
(3) Command Line:-
You can also find the Python version from the command line by running the following command:

python --version

This will print the Python version to the terminal
'''

'''
(4) Jupyter Notebook or IPython:
If you are using Jupyter Notebook or IPython, you can use the ! prefix to run shell commands.
To check the Python version, you can use:

# !python --version

Or within a cell, you can use the ! prefix before the command.
'''

# %%
'''[Q9-answer:-]'''

#python supports the creation of anonymous functions at runtime, using a construct called?

'''
Python supports the creation of anonymous functions at runtime using a construct called "lambda" functions.
Lambda functions are also known as lambda expressions or anonymous functions because
they don't have a name like regular functions defined with the def keyword. Instead,
they are defined using the lambda keyword followed by one or more arguments and an expression.

Here's the basic syntax of a lambda function:
'''
lambda arguments: expression

'''
Here's a simple example of a lambda function that adds two numbers:
'''
add = lambda x, y: x + y
result = add(5, 3)
print(result)  # Output: 8

# %%
'''[Q10-answer:-]'''

#what does pip stand for python?

'''
"Pip" is a package manager used for installing and managing Python packages and libraries.
The name "pip" itself doesn't stand for anything specific; it's a recursive acronym that stands for
"Pip Installs Packages" or "Pip Installs Python." It's a tool that simplifies the process of
installing, upgrading, and managing Python packages from the Python Package Index (PyPI) and other sources.

You can use pip to install packages like this:
'''
pip install package_name
'''
It will download and install the specified Python package and its dependencies, making it a crucial tool for Python
developers to manage their project dependencies efficiently.'''

# %%
'''[Q11-answer:-]'''

#Mention a few built in functions in python?
'''
Python provides a wide range of built-in functions that are available for you to use without needing to
import any external modules. Here are a few commonly used built-in functions in Python:

(1) print(): Used for printing output to the console.
'''
print("Hello, World!")

'''
(2) len(): Returns the length (number of items) of an object, such as a string, list, or tuple.
'''
my_list = [1, 2, 3, 4, 5]
length = len(my_list)

'''
(3) type(): Returns the type of an object.
'''
x = 10
data_type = type(x)

'''
(4) input(): Reads a line of text from the user's input.
'''
name = input("Enter your name: ")

'''
(5) int(), float(), str(): Used for type conversion between different data types.
'''
x = "42"
int_x = int(x)

'''
(6) range(): Generates a sequence of numbers.
'''
numbers = list(range(1, 6))  # Creates a list [1, 2, 3, 4, 5]

'''
(7) max() and min(): Find the maximum and minimum values in a sequence.
'''
numbers = [3, 7, 1, 9, 4]
max_value = max(numbers)
min_value = min(numbers)

'''
(8) sum(): Calculates the sum of elements in an iterable.
'''
numbers = [1, 2, 3, 4, 5]
total = sum(numbers)

'''
(9) abs(): Returns the absolute value of a number.
'''
x = -10
absolute_x = abs(x)

'''
(10) sorted(): Sorts an iterable.
'''
numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
sorted_numbers = sorted(numbers)
'''
These are just a few of the many built-in functions in Python. The Python standard library offers a
rich collection of functions for various tasks, making it a versatile and powerful programming language.
'''

# %%
'''[Q12-answer:-]'''

#what is the maximum possible length of an identifier in python in short?
'''
In Python, there is no fixed maximum length for identifiers (such as variable names, function names, etc.).
The length is practically limited by available memory and code readability guidelines.
However, PEP 8 recommends keeping line lengths, including identifiers, within 79 characters for code readability
'''

# %%
'''[Q13-answer:-]'''

#what are the benefits of using python?
'''

Python is a popular programming language known for its simplicity, versatility, and wide range of applications.
Here are some of the key benefits of using Python:

(1) simple and easy to learn
(2) freeware and open source
(3) High level programing language
(4) platform independent
(5) portability
(6) Dynamicallyy typed
(7) Both procedure oriented and object oriented
(8) Interpreted
(9) Extensible
'''

# %%
'''[Q14-answer:-]'''

#How is memory managed in python?
'''
Memory management in Python is automatic and involves the following key mechanisms:

(1) Reference Counting: Objects in Python have a reference count, and memory is deallocated
when an object's reference count reaches zero.
(2) Garbage Collection: Python employs a garbage collector to identify and collect unreachable objects
and break circular references.
(3) Memory Pools: Small objects are allocated from memory pools to reduce fragmentation and improve allocation speed.
(4) Cyclic Garbage Collector: Detects and cleans up circular references to prevent memory leaks.
(5) Memory Optimization: Python aims to optimize memory usage by reusing memory when possible.

Overall, Python's memory management is designed to be automatic and efficient, 
but developers should be mindful of circular references and large data structures.
'''

# %%
'''[Q15-answer:-]'''

#how to install python on windows and set path variables

'''
To install Python on Windows and set the necessary path variables, you can follow these steps:

(1) Download Python
       -> Go to the official Python website: https://www.python.org/downloads/windows/
       -> Download the latest stable version of Python for Windows (e.g., Python 3.9.6).
       -> Choose the appropriate installer:
           - If you have a 64-bit version of Windows, download the "Windows x86-64 executable installer."
           - If you have a 32-bit version of Windows, download the "Windows x86 executable installer."
(2) Run the Installer:
       -> Locate the downloaded installer file (e.g., python-3.9.6-amd64.exe) and double-click on it to run it.
       -> Check the box that says "Add Python 3.x to PATH" during installation. This option ensures that Python is added to your system's PATH environment variable, allowing you to run Python from the Command Prompt or PowerShell without specifying the full path.
(3) Install Python:
       -> Click the "Install Now" button to start the installation.
       -> Python will be installed to the default location, typically in the "
          C:\Users<YourUsername>\AppData\Local\Programs\Python\Python3.x" directory.
(4) Verify the Installation:
       -> Open a Command Prompt or PowerShell window.
       -> Type the following command to check the Python version:
                - python --version
                
       -> You should see the installed Python version displayed.
(5) Set Environment Variables (Optional):
       -> If you need to manually set or modify environment variables, you can do so by following these steps:
               - Right-click on "This PC" (or "My Computer") and select "Properties."
               - Click on "Advanced system settings" on the left side.
               - In the "System Properties" window, click the "Environment Variables" button.
               - In the "User Variables" section, scroll down and look for "Path." Select it and click the "Edit" button.
               - Click "New" and add the path to your Python installation directory. For example, if Python is installed in "C:\Users<YourUsername>\AppData\Local\Programs\Python\Python3.x," add that path.
               - Click "OK" to close all the windows.
(6) Verify Path Variable (Optional):
       -> To ensure the PATH variable is correctly set, open a new Command Prompt or PowerShell window and run:
                    python
                    
       -> This should start the Python interpreter.
That's it! You've successfully installed Python on your Windows system and, if needed,
set the PATH variable. You can now start writing and running Python code on your Windows machine.
'''

# %%
'''[Q16-answer:-]'''

#Is indentation required in python?
'''
Yes, indentation is required in Python. Indentation is not just a coding convention or style recommendation;
it is a fundamental part of the Python language's syntax.

In Python, indentation is used to define the scope and structure of code blocks, such as 
those within functions, loops, conditional statements, and classes. Indentation is how Python groups
statements together, and it is used in place of curly braces {} or other block delimiters found in some
other programming languages.

Here's an example of Python code that uses indentation to define a code block within a function:
'''
def greet(name):
    if name == "Alice":
        print("Hello, Alice!")
    else:
        print("Hello, stranger!")

# The indentation defines the scope of the 'greet' function and the 'if' statement.
